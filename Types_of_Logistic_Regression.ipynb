# %% [markdown]
# <a href="https://colab.research.google.com/github/KenDaupsey/Types-of-Logistic-Regression/blob/main/Types_of_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *** Types of Logistic Regression ***

# %% [markdown]
# *** Simple Logistic Regression
# Multiple Logistic Regression
# Ordered logistic regression
# Multinomial Logistic Regression (mlogit)
# ***

# %% [markdown]
# *** Simple Logistic Regression ***

# %%
### Import Necessary Libraries
import pandas as pd
import numpy as np

# %%
# Load the dataset from GitHub URL
url = "https://raw.githubusercontent.com/KenDaupsey/Types-of-Logistic-Regression/main/hsb2%7Edata.csv"
df = pd.read_csv(url)
df.head()
# Out:
#     id  female   race     ses  schtyp      prog  read  write  math  science  \
# 0   70    male  white     low  public   general    57     52    41       47
# 1  121  female  white  middle  public  vocation    68     59    53       63
# 2   86    male  white    high  public   general    44     33    54       58
# 3  141    male  white    high  public  vocation    63     44    47       53
# 4  172    male  white  middle  public  academic    47     52    57       53
#
#    socst
# 0     57
# 1     61
# 2     31
# 3     56
# 4     61

# %%
df.columns
# Out:
# Index(['id', 'female', 'race', 'ses', 'schtyp', 'prog', 'read', 'write',
#        'math', 'science', 'socst'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       200 non-null    int64
#  1   female   200 non-null    object
#  2   race     200 non-null    object
#  3   ses      200 non-null    object
#  4   schtyp   200 non-null    object
#  5   prog     200 non-null    object
#  6   read     200 non-null    int64
#  7   write    200 non-null    int64
#  8   math     200 non-null    int64
#  9   science  200 non-null    int64
#  10  socst    200 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 17.3+ KB

# %%
##### Convert Continous Variable "math" Into Binary Variable
#import pandas as pd

# Assuming df is your DataFrame
# Define the ranges for categories
category_ranges = [0, 49, 100]  # Adjust the ranges as needed

# Define the corresponding labels for categories
category_labels = [0, 1]

# Create the 'math2' column using the cut function
df['math2'] = pd.cut(df['math'], bins=category_ranges, labels=category_labels, include_lowest=True)

# Display the first few rows to verify the changes
print(df[['math', 'math2']].head())
# Out:
#    math math2
# 0    41     0
# 1    53     1
# 2    54     1
# 3    47     0
# 4    57     1

# %%
df.head()
# Out:
#     id  female   race     ses  schtyp      prog  read  write  math  science  \
# 0   70    male  white     low  public   general    57     52    41       47
# 1  121  female  white  middle  public  vocation    68     59    53       63
# 2   86    male  white    high  public   general    44     33    54       58
# 3  141    male  white    high  public  vocation    63     44    47       53
# 4  172    male  white  middle  public  academic    47     52    57       53
#
#    socst math2
# 0     57     0
# 1     61     1
# 2     31     1
# 3     56     0
# 4     61     1

# %%
# Logistic Regression Procedure
import statsmodels.api as sm

X = df['write']  # Independent variable
y = df['math2']   # Dependent variable

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Fit simple logistic regression model
logit_model = sm.Logit(y, X)
result = logit_model.fit()

# Print the summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.518529
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                  math2   No. Observations:                  200
# Model:                          Logit   Df Residuals:                      198
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2295
# Time:                        18:48:13   Log-Likelihood:                -103.71
# converged:                       True   LL-Null:                       -134.60
# Covariance Type:            nonrobust   LLR p-value:                 3.816e-15
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -6.9307      1.113     -6.228      0.000      -9.112      -4.750
# ...

# %% [markdown]
# *** Multiple Logistic Regression ***

# %%
### Create new dataset, a copy of “df”
df6=df.copy()

# %%
df6.columns
# Out:
# Index(['id', 'female', 'race', 'ses', 'schtyp', 'prog', 'read', 'write',
#        'math', 'science', 'socst', 'math2'],
#       dtype='object')

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming df is your DataFrame
df6['math2'] = (df6['math'] >= 50).astype(int)

df6.head()
# Out:
#     id  female   race     ses  schtyp      prog  read  write  math  science  \
# 0   70    male  white     low  public   general    57     52    41       47
# 1  121  female  white  middle  public  vocation    68     59    53       63
# 2   86    male  white    high  public   general    44     33    54       58
# 3  141    male  white    high  public  vocation    63     44    47       53
# 4  172    male  white  middle  public  academic    47     52    57       53
#
#    socst  math2
# 0     57      0
# 1     61      1
# 2     31      1
# 3     56      0
# 4     61      1

# %%
df6['math2'].value_counts()
# Out:
# 1    120
# 0     80
# Name: math2, dtype: int64

# %%
### MULTIPLE LOGISTIC REGRESSION

import statsmodels.api as sm
import pandas as pd

# Assuming df is your DataFrame
### Notice that we use a slightly different method to determine pass or fail as seen below
df6['math2'] = (df6['math'] >= 49).astype(int)

# Define predictor variable and add a constant term
X = sm.add_constant(df6[['write', 'read', 'socst']])
y = df6['math2']

# Fit Simple Logistic Regression model
logit_model = sm.Logit(y, X)
result = logit_model.fit()

# Print the summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.433786
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:                  math2   No. Observations:                  200
# Model:                          Logit   Df Residuals:                      196
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.3300
# Time:                        18:48:24   Log-Likelihood:                -86.757
# converged:                       True   LL-Null:                       -129.49
# Covariance Type:            nonrobust   LLR p-value:                 2.063e-18
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -10.1894      1.546     -6.592      0.000     -13.219      -7.160
# ...

# %% [markdown]
# *** Ordered logistic regression ***

# %%
### Import Necessaary Libraries
import numpy as np
import pandas as pd

# %%
# Load the dataset from GitHub URL
url = "https://raw.githubusercontent.com/KenDaupsey/Types-of-Logistic-Regression/main/hsb2%7Edata.csv"
df = pd.read_csv(url)
df.head()
# Out:
#     id  female   race     ses  schtyp      prog  read  write  math  science  \
# 0   70    male  white     low  public   general    57     52    41       47
# 1  121  female  white  middle  public  vocation    68     59    53       63
# 2   86    male  white    high  public   general    44     33    54       58
# 3  141    male  white    high  public  vocation    63     44    47       53
# 4  172    male  white  middle  public  academic    47     52    57       53
#
#    socst
# 0     57
# 1     61
# 2     31
# 3     56
# 4     61

# %%
df.columns
# Out:
# Index(['id', 'female', 'race', 'ses', 'schtyp', 'prog', 'read', 'write',
#        'math', 'science', 'socst'],
#       dtype='object')

# %%
## Creating New “write3” from ”write”
import pandas as pd
import statsmodels.api as sm

# Assuming df is your DataFrame
# Generate write3
df['write3'] = 1
df.loc[(df['write'] >= 49) & (df['write'] <= 57), 'write3'] = 2
df.loc[(df['write'] >= 58) & (df['write'] <= 70), 'write3'] = 3

df.head()
# Out:
#     id  female   race     ses  schtyp      prog  read  write  math  science  \
# 0   70    male  white     low  public   general    57     52    41       47
# 1  121  female  white  middle  public  vocation    68     59    53       63
# 2   86    male  white    high  public   general    44     33    54       58
# 3  141    male  white    high  public  vocation    63     44    47       53
# 4  172    male  white  middle  public  academic    47     52    57       53
#
#    socst  write3
# 0     57       2
# 1     61       3
# 2     31       1
# 3     56       1
# 4     61       2

# %%
df.columns
# Out:
# Index(['id', 'female', 'race', 'ses', 'schtyp', 'prog', 'read', 'write',
#        'math', 'science', 'socst', 'write3'],
#       dtype='object')

# %%
df['write3'].value_counts()
# Out:
# 3    78
# 2    61
# 1    61
# Name: write3, dtype: int64

# %%
# Perform multinomial logistic regression
model = sm.MNLogit.from_formula('write3 ~ female + read + socst', data=df)
result = model.fit()

# Print the summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.777398
#          Iterations 7
#                           MNLogit Regression Results
# ...
# Dep. Variable:                 write3   No. Observations:                  200
# Model:                        MNLogit   Df Residuals:                      192
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2878
# Time:                        18:49:57   Log-Likelihood:                -155.48
# converged:                       True   LL-Null:                       -218.31
# Covariance Type:            nonrobust   LLR p-value:                 1.049e-24
# ...
#       write3=2       coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -6.4769      1.531     -4.232      0.000      -9.477      -3.477
# ...

# %% [markdown]
# *** Another Ordered Regression Procedure ***

# %%
### Import Necessary Libraries
import pandas as pd
import numpy as np

# %%
### Load Dataset
url= "https://raw.githubusercontent.com/KenDaupsey/Types-of-Logistic-Regression/main/MultionmialRegression%7EDataset.csv"
df = pd.read_csv(url)
df.head()
# Out:
#     id  female     ses  schtyp      prog  read  write  math  science  socst  \
# 0   45  female     low  public  vocation    34     35    41       29     26
# 1  108    male  middle  public   general    34     33    41       36     36
# 2   15    male    high  public  vocation    39     39    44       26     42
# 3   67    male     low  public  vocation    37     37    42       33     32
# 4  153    male  middle  public  vocation    39     31    40       39     51
#
#          honors  awards  cid
# 0  not enrolled       0    1
# 1  not enrolled       0    1
# 2  not enrolled       0    1
# 3  not enrolled       0    1
# 4  not enrolled       0    1

# %%
### Import Library for Multinomial Logistic Regression Procedure
from statsmodels.miscmodels.ordinal_model import OrderedModel

# %%
df.describe().T
# Out:
#          count     mean        std   min    25%    50%     75%    max
# id       200.0  100.500  57.879185   1.0  50.75  100.5  150.25  200.0
# read     200.0   52.230  10.252937  28.0  44.00   50.0   60.00   76.0
# write    200.0   52.775   9.478586  31.0  45.75   54.0   60.00   67.0
# math     200.0   52.645   9.368448  33.0  45.00   52.0   59.00   75.0
# science  200.0   51.850   9.900891  26.0  44.00   53.0   58.00   74.0
# socst    200.0   52.405  10.735793  26.0  46.00   52.0   61.00   71.0
# awards   200.0    1.670   1.818691   0.0   0.00    1.0    2.00    7.0
# cid      200.0   10.430   5.801152   1.0   5.00   10.5   15.00   20.0

# %%
df.dtypes
# Out:
# id          int64
# female     object
# ses        object
# schtyp     object
# prog       object
# read        int64
# write       int64
# math        int64
# science     int64
# socst       int64
# honors     object
# awards      int64
# cid         int64
# dtype: object

# %%
# Convert 'female' column to categorical dtype
df['female'] = df['female'].astype('category')

# Now you can use the .cat accessor to access the category codes
df['female'] = df['female'].cat.codes

# Check the data types
print(df.dtypes)
# Out:
# id          int64
# female       int8
# ses        object
# schtyp     object
# prog       object
# read        int64
# write       int64
# math        int64
# science     int64
# socst       int64
# honors     object
# awards      int64
# cid         int64
# dtype: object

# %%
# Convert input data to numpy arrays
endog = np.asarray(df['cid'])
exog = np.asarray(df[['female', 'write',  'read',  'math']])

# Fit the ordered probit model
mod_probit = OrderedModel(endog, exog, distr='probit')
res_probit = mod_probit.fit(method='bfgs')

# Fit the ordered logistic regression model
mod_logit = OrderedModel(endog, exog, distr='logit')
res_logit = mod_logit.fit(method='bfgs')

# Compare the model summaries
print(res_probit.summary())
print(res_logit.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 1.512793
#          Iterations: 52
#          Function evaluations: 56
#          Gradient evaluations: 56
# Optimization terminated successfully.
#          Current function value: 1.520993
#          Iterations: 85
#          Function evaluations: 91
#          Gradient evaluations: 91
#                              OrderedModel Results
# ...
# Dep. Variable:                      y   Log-Likelihood:                -302.56
# Model:                   OrderedModel   AIC:                             651.1
# Method:            Maximum Likelihood   BIC:                             727.0
# Date:                Mon, 04 Mar 2024
# Time:                        18:54:18
# No. Observations:                 200
# Df Residuals:                     177
# Df Model:                           4
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
### Model Performance Evaluation Using Information Criteria
# Evaluate Model Performance using AIC and BIC
print("AIC - Ordered Probit Model:", res_probit.aic)
print("BIC - Ordered Probit Model:", res_probit.bic)

print("AIC - Ordered Logistic Regression Model:", res_logit.aic)
print("BIC - Ordered Logistic Regression Model:", res_logit.bic)
# Out:
# AIC - Ordered Probit Model: 651.1171130528694
# BIC - Ordered Probit Model: 726.9784124834742
# AIC - Ordered Logistic Regression Model: 654.3972673450891
# BIC - Ordered Logistic Regression Model: 730.2585667756939

# %%
### Calculate the differences in AIC and BIC between the ordered logistic regression and ordered probit models
delta_AIC = res_logit.aic - res_probit.aic
delta_BIC = res_logit.bic - res_probit.bic
print("ΔAIC:", delta_AIC)
print("ΔBIC:", delta_BIC)
# Out:
# ΔAIC: 3.280154292219663
# ΔBIC: 3.280154292219663

# %% [markdown]
# *** Multinomial Logistic Regression (MNlogit) ***

# %%
### Import Necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### Load Dataset and Examine fiors 5 Rows
url= "https://raw.githubusercontent.com/KenDaupsey/Types-of-Logistic-Regression/main/multiclassification%7Ecustomer%7Edata.csv"

df = pd.read_csv(url)
df.head()
# Out:
#    Age Education_Level Marital_Status  Credit_Score  Annual_Income  \
# 0   58        Graduate       Divorced           771          48843
# 1   44     High School       Divorced           680          52526
# 2   28         College        Married           682          56526
# 3   50        Graduate        Married           526          38623
# 4   48        Graduate        Married           720          62126
#
#    Savings_Amount Income_Category Health_Status
# 0           -1306             Low          Poor
# 1            5489             Low          Poor
# 2            8095             Low          Good
# 3           12731             Low          Poor
# 4            6248            High          Good

# %%
df.columns
# Out:
# Index(['Age', 'Education_Level', 'Marital_Status', 'Credit_Score',
#        'Annual_Income', 'Savings_Amount', 'Income_Category', 'Health_Status'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                  count       mean           std      min       25%      50%  \
# Age             1000.0     46.840     15.246273     21.0     30.00     49.0
# Credit_Score    1000.0    699.424     48.861515    526.0    666.00    699.5
# Annual_Income   1000.0  50024.192  10011.540018  20955.0  43241.00  49699.5
# Savings_Amount  1000.0   9934.906   4894.791449  -6375.0   6673.25   9953.0
#
#                      75%      max
# Age                58.00     70.0
# Credit_Score      735.00    853.0
# Annual_Income   56994.50  77660.0
# Savings_Amount  13180.75  25074.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              1000 non-null   int64
#  1   Education_Level  1000 non-null   object
#  2   Marital_Status   1000 non-null   object
#  3   Credit_Score     1000 non-null   int64
#  4   Annual_Income    1000 non-null   int64
#  5   Savings_Amount   1000 non-null   int64
#  6   Income_Category  1000 non-null   object
#  7   Health_Status    1000 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
### Encoding Categorical Variables
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Convert categorical variables to integers
df['Education_Level'] = label_encoder.fit_transform(df['Education_Level'])
df['Marital_Status'] = label_encoder.fit_transform(df['Marital_Status'])
df['Income_Category'] = label_encoder.fit_transform(df['Income_Category'])
df['Health_Status'] = label_encoder.fit_transform(df['Health_Status'])

# Display the modified dataframe
print(df.head())
# Out:
#    Age  Education_Level  Marital_Status  Credit_Score  Annual_Income  \
# 0   58                1               0           771          48843
# 1   44                2               0           680          52526
# 2   28                0               1           682          56526
# 3   50                1               1           526          38623
# 4   48                1               1           720          62126
#
#    Savings_Amount  Income_Category  Health_Status
# 0           -1306                1              2
# 1            5489                1              2
# 2            8095                1              1
# 3           12731                1              2
# 4            6248                0              1

# %%
df.dtypes
# Out:
# Age                int64
# Education_Level    int64
# Marital_Status     int64
# Credit_Score       int64
# Annual_Income      int64
# Savings_Amount     int64
# Income_Category    int64
# Health_Status      int64
# dtype: object

# %%
df['Health_Status'].value_counts()
# Out:
# 2    536
# 1    338
# 0    126
# Name: Health_Status, dtype: int64

# %%
### The Multinomial Logistic Regression Procedure
# Extract independent and dependent variables
X = df[['Age', 'Education_Level', 'Marital_Status', 'Credit_Score',
       'Annual_Income', 'Savings_Amount', 'Income_Category',]]
y = df['Health_Status']

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Fit multinomial logistic regression model
model = sm.MNLogit(y, X)
result = model.fit()

# Print the summary
print(result.summary())
# Out:
# ...
#          Current function value: 0.483882
#          Iterations: 35
#                           MNLogit Regression Results
# ...
# Dep. Variable:          Health_Status   No. Observations:                 1000
# Model:                        MNLogit   Df Residuals:                      984
# Method:                           MLE   Df Model:                           14
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.4970
# Time:                        18:56:46   Log-Likelihood:                -483.88
# converged:                      False   LL-Null:                       -961.90
# Covariance Type:            nonrobust   LLR p-value:                4.215e-195
# ...
# Health_Status=1       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              41.1967    3.5e+04      0.001      0.999   -6.85e+04    6.86e+04
# ...

# %%
### test for proportional odds
import statsmodels.api as sm

# Specify the formula for proportional odds logistic regression
formula = 'Health_Status ~ Age + Education_Level + Marital_Status + Credit_Score + Annual_Income + Savings_Amount'
# Fit the proportional odds logistic regression model
model = sm.OLS.from_formula(formula, data=df).fit()

# Print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Health_Status   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     54.17
# Date:                Mon, 04 Mar 2024   Prob (F-statistic):           6.78e-58
# Time:                        18:56:47   Log-Likelihood:                -924.66
# No. Observations:                1000   AIC:                             1863.
# Df Residuals:                     993   BIC:                             1898.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           4.1476      0.305     13.579      0.000       3.548       4.747
# ...
